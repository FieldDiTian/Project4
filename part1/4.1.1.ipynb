# %%
'''>>>>> start CodeP3.2F25
    V.P. Carey ME249, Fall 2025

Intro to Neural Network Modeling 
Keras model for PV power system'''

#import useful packages
import keras
import pandas as pd
from keras.models import Sequential
import numpy as np
import keras.backend as kb
import tensorflow as tf
#the follwoing 2 lines are only needed for Mac OS machines
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# (b) Import full dataset from CodeP4.1F25.ipynb and calculate medians
xdata_full = [[-10.0, 1550, 4.464],  
  [-10.0, 1850, 4.464], 
  [10.0, 1550, 4.464], 
  [10.0, 1850, 4.464], 
  [30.0, 1550, 4.464], 
  [30.0, 1850, 4.464], 
  [-10.0, 1550, 6.696], 
  [-10.0, 1850, 6.696], 
  [10.0, 1550, 6.695], 
  [10.0, 1850, 6.696], 
  [30.0, 1550, 6.696], 
  [30.0, 1850, 6.698], 
  [-10.0, 1550, 8.928], 
  [-10.0, 1850, 8.928],   
  [10.0, 1550, 8.928], 
  [10.0, 1850, 8.928], 
  [30.0, 1550, 8.928], 
  [30.0, 1850, 8.928],
  [-10.0, 350, 4.464], 
  [-10.0, 650, 4.464], 
  [-10.0, 950, 4.464], 
  [-10.0, 1250, 4.464], 
  [10.0, 350, 4.464], 
  [10.0, 650, 4.464], 
  [10.0, 950, 4.464], 
  [10.0, 1250, 4.464], 
  [30.0, 350, 4.464], 
  [30.0, 650, 4.464], 
  [30.0, 950, 4.464], 
  [30.0, 1250, 4.466], 
  [-10.0, 350, 6.696], 
  [-10.0, 650, 6.696], 
  [-10.0, 950, 6.696], 
  [-10.0, 1250, 6.696], 
  [10.0, 350, 6.696], 
  [10.0, 650, 6.696], 
  [10.0, 950, 6.696], 
  [10.0, 1250, 6.696], 
  [30.0, 350, 6.696], 
  [30.0, 650, 6.696], 
  [30.0, 950, 6.696], 
  [30.0, 1250, 6.696], 
  [-10.0, 350, 8.928], 
  [-10.0, 650, 8.928], 
  [-10.0, 950, 8.928], 
  [-10.0, 1250, 8.928], 
  [10.0, 350, 8.928], 
  [10.0, 650, 8.928], 
  [10.0, 950, 8.928], 
  [10.0, 1250, 8.928], 
  [30.0, 350, 8.928], 
  [30.0, 650, 8.928], 
  [30.0, 950, 8.928], 
  [30.0, 1250, 8.928]]

ydata_full = [[26.1, 152.8], 
 [26.5, 172.7], 
 [27.9, 191.4], 
 [28.3, 198.0], 
 [29.6, 217.8], 
 [30.1, 224.4],  
 [26.9, 118.8], 
 [27.2, 122.1], 
 [28.8, 136.4], 
 [29.1, 139.6], 
 [30.6, 154.0], 
 [31.0, 158.4],  
 [27.3, 92.4], 
 [27.6, 94.6], 
 [29.2, 105.6], 
 [29.6, 107.8], 
 [31.1, 119.9], 
 [31.5, 123.2],
 [18.9, 80.3], 
 [23.5, 124.6], 
 [24.8, 138.6], 
 [25.6, 146.9], 
 [19.2, 83.1], 
 [25.0, 140.5], 
 [26.5, 157.6], 
 [27.3, 167.5],  
 [19.4, 84.7], 
 [26.4, 156.7], 
 [28.1, 177.7], 
 [29.0, 189.4],
 [22.4, 75.2], 
 [24.8, 92.2], 
 [25.8, 99.7], 
 [26.4, 104.6], 
 [23.6, 83.7], 
 [26.5, 104.9], 
 [27.6, 113.8], 
 [28.3, 119.6], 
 [24.8, 92.0], 
 [28.1, 118.2], 
 [29.3, 128.8], 
 [30.1, 135.5],  
 [23.5, 62.2], 
 [25.4, 72.5], 
 [26.3, 77.6], 
 [26.9, 81.1],  
 [25.0, 70.3], 
 [27.1, 82.7], 
 [28.1, 88.7], 
 [28.7, 92.8],  
 [26.5, 78.6], 
 [28.8, 93.5], 
 [29.9, 100.5], 
 [30.6, 105.2]]

# Convert to numpy arrays to calculate medians
xarray_full = np.array(xdata_full)
yarray_full = np.array(ydata_full)

# Define median values of input variables
Tamed = np.median(xarray_full[:, 0])
IDmed = np.median(xarray_full[:, 1])
RLmed = np.median(xarray_full[:, 2])

# Define median values of output variables
VLmed = np.median(yarray_full[:, 0])
Wdmed = np.median(yarray_full[:, 1])

# (b) Normalize data by dividing by medians
xdata_normalized = xarray_full / np.array([Tamed, IDmed, RLmed])
ydata_normalized = yarray_full / np.array([VLmed, Wdmed])

# (c) Randomly split normalized data into training set (2/3) and validation set (1/3)
np.random.seed(42)
indices = np.random.permutation(len(xdata_normalized))
train_size = int(len(xdata_normalized) * 2 / 3)

train_indices = indices[:train_size]
val_indices = indices[train_size:]

xarray = xdata_normalized[train_indices]
yarray = ydata_normalized[train_indices]
xarray_val = xdata_normalized[val_indices]
yarray_val = ydata_normalized[val_indices]

print (xarray)
print (yarray)
# Out:
# [[-1.          0.59090909  0.66666667]
#  [ 1.          1.13636364  1.33333333]
#  [ 1.          0.86363636  1.33333333]
#  [-1.          1.40909091  1.33333333]
#  [-1.          0.86363636  1.33333333]
#  [ 3.          1.68181818  0.66666667]
#  [ 3.          1.68181818  1.33333333]
#  [ 3.          0.86363636  1.33333333]
#  [ 1.          1.68181818  0.66666667]
#  [-1.          0.86363636  1.        ]
#  [-1.          1.68181818  1.33333333]
#  [ 1.          1.40909091  0.99985066]
#  [ 3.          0.31818182  0.66666667]
#  [-1.          1.40909091  1.        ]
#  [ 1.          0.31818182  1.        ]
#  [ 3.          1.40909091  0.66666667]
#  [ 1.          1.13636364  1.        ]
#  [ 1.          0.86363636  0.66666667]
#  [-1.          1.13636364  1.33333333]
#  [-1.          1.13636364  1.        ]
#  [ 3.          0.31818182  1.33333333]
#  [ 1.          1.68181818  1.33333333]
#  [ 1.          1.68181818  1.        ]
#  [ 3.          1.40909091  1.33333333]
#  [-1.          0.31818182  1.        ]
#  [ 1.          0.86363636  1.        ]
#  [ 1.          1.13636364  0.66666667]
#  [ 3.          1.68181818  1.00029869]
#  [-1.          1.40909091  0.66666667]
#  [ 1.          0.59090909  1.33333333]
#  [ 3.          0.59090909  0.66666667]
#  [-1.          0.59090909  1.        ]
#  [ 3.          0.86363636  1.        ]
#  [ 3.          1.13636364  0.66696535]
#  [ 1.          0.31818182  1.33333333]
#  [-1.          1.68181818  0.66666667]]
# [[0.86238532 1.07413793]
#  [1.05321101 0.8       ]
#  [1.03119266 0.76465517]
#  [1.00183486 0.79655172]
#  [0.96513761 0.66896552]
#  [1.10458716 1.93448276]
#  [1.1559633  1.06206897]
#  [1.09724771 0.86637931]
#  [1.03853211 1.70689655]
#  [0.94678899 0.85948276]
#  [1.01284404 0.81551724]
#  [1.05688073 1.17586207]
#  [0.71192661 0.73017241]
#  [0.98715596 1.02413793]
#  [0.86605505 0.72155172]
#  [1.08623853 1.87758621]
#  [1.03853211 1.03103448]
#  [0.97247706 1.35862069]
#  [0.98715596 0.69913793]
#  [0.96880734 0.90172414]
#  [0.97247706 0.67758621]
#  [1.08623853 0.92931034]
#  [1.06788991 1.20344828]
#  [1.1412844  1.03362069]
#  [0.82201835 0.64827586]
#  [1.01284404 0.98103448]
#  [1.00183486 1.44396552]
#  [1.13761468 1.36551724]
#  [0.95779817 1.31724138]
#  [0.99449541 0.71293103]
#  [0.96880734 1.35086207]
#  [0.91009174 0.79482759]
#  [1.07522936 1.11034483]
#  [1.06422018 1.63275862]
#  [0.91743119 0.60603448]
#  [0.97247706 1.4887931 ]]

# %%
# (d) Define neural network model

from keras import backend as K
# Initialize weights with values between -0.25 and 0.25
initializer = keras.initializers.RandomUniform(minval= -0.25, maxval=0.25)

# Create Sequential model with specified architecture:
# - Inlet layer: 6 neurons, activation='elu', input_shape=[3]
# - 3 Hidden layers: 8, 14, and 8 neurons
# - Outlet layer: 2 neurons, no activation function
model = keras.Sequential([
    keras.layers.Dense(6, activation='elu', input_shape=[3],  kernel_initializer=initializer),
    keras.layers.Dense(8, activation='elu',  kernel_initializer=initializer),
    keras.layers.Dense(14, activation='elu', kernel_initializer=initializer),
    keras.layers.Dense(8, activation='elu', kernel_initializer=initializer),
    keras.layers.Dense(2,  kernel_initializer=initializer)
  ])

# %%
# Compile model with RMSprop optimizer and mean absolute error loss
rms = keras.optimizers.RMSprop(0.0009)
model.compile(loss='mean_absolute_error',optimizer=rms)

# %%
# (e) Train the neural network model using model.fit with backpropagation

# Add early stopping callback - monitor validation loss
es = keras.callbacks.EarlyStopping(
    monitor='loss', 
    mode='min', 
    patience = 100,
    restore_best_weights = True, 
    verbose=1)

# Add checkpoint to save best model - monitor validation loss
mc = keras.callbacks.ModelCheckpoint('best_model.keras', monitor='val_loss', 
                     mode='min',  verbose=1, save_best_only=True)

# Train model with validation data
historyData = model.fit(xarray, yarray,
                       validation_data=(xarray_val, yarray_val),
                       epochs=3000,
                       callbacks=[es, mc])

# Extract loss history
loss_hist = historyData.history['loss']
val_loss_hist = historyData.history['val_loss']
best_epoch = np.argmin(val_loss_hist) + 1
print ('best epoch = ', best_epoch)
print('smallest training loss =', np.min(loss_hist))

print('smallest validation loss =', np.min(val_loss_hist))

model.save('./best_model.keras')
# Save model
# Out:
# Epoch 1/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - loss: 1.0193
# Epoch 1: val_loss improved from None to 0.97262, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 1.0269 - val_loss: 0.9726
# Epoch 2/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0199
# Epoch 2: val_loss improved from 0.97262 to 0.96092, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.0104 - val_loss: 0.9609
# Epoch 3/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9680
# Epoch 3: val_loss improved from 0.96092 to 0.94909, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.9984 - val_loss: 0.9491
# Epoch 4/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9582
# Epoch 4: val_loss improved from 0.94909 to 0.93806, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.9865 - val_loss: 0.9381
# Epoch 5/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9468
# Epoch 5: val_loss improved from 0.93806 to 0.92618, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.9751 - val_loss: 0.9262
# Epoch 6/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9653
# Epoch 6: val_loss improved from 0.92618 to 0.91460, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.9631 - val_loss: 0.9146
# Epoch 7/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9495
# Epoch 7: val_loss improved from 0.91460 to 0.90176, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.9511 - val_loss: 0.9018
# Epoch 8/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9444
# Epoch 8: val_loss improved from 0.90176 to 0.88881, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.9379 - val_loss: 0.8888
# Epoch 9/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9235
# Epoch 9: val_loss improved from 0.88881 to 0.87474, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.9245 - val_loss: 0.8747
# Epoch 10/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9100
# Epoch 10: val_loss improved from 0.87474 to 0.85924, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.9099 - val_loss: 0.8592
# Epoch 11/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8900
# Epoch 11: val_loss improved from 0.85924 to 0.84233, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.8939 - val_loss: 0.8423
# Epoch 12/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8843
# Epoch 12: val_loss improved from 0.84233 to 0.82534, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.8766 - val_loss: 0.8253
# Epoch 13/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8618
# Epoch 13: val_loss improved from 0.82534 to 0.80747, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.8591 - val_loss: 0.8075
# Epoch 14/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8380
# Epoch 14: val_loss improved from 0.80747 to 0.78895, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.8407 - val_loss: 0.7889
# Epoch 15/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8151
# Epoch 15: val_loss improved from 0.78895 to 0.76760, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.8213 - val_loss: 0.7676
# Epoch 16/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8103
# Epoch 16: val_loss improved from 0.76760 to 0.74499, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.7993 - val_loss: 0.7450
# Epoch 17/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7838
# Epoch 17: val_loss improved from 0.74499 to 0.72185, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.7760 - val_loss: 0.7219
# Epoch 18/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7552
# Epoch 18: val_loss improved from 0.72185 to 0.69740, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.7520 - val_loss: 0.6974
# Epoch 19/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.7338
# Epoch 19: val_loss improved from 0.69740 to 0.67083, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.7266 - val_loss: 0.6708
# Epoch 20/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7115
# Epoch 20: val_loss improved from 0.67083 to 0.64011, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.6987 - val_loss: 0.6401
# Epoch 21/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6820
# Epoch 21: val_loss improved from 0.64011 to 0.61146, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.6675 - val_loss: 0.6115
# Epoch 22/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6412
# Epoch 22: val_loss improved from 0.61146 to 0.57947, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.6375 - val_loss: 0.5795
# Epoch 23/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6146
# Epoch 23: val_loss improved from 0.57947 to 0.54431, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.6042 - val_loss: 0.5443
# Epoch 24/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5774
# Epoch 24: val_loss improved from 0.54431 to 0.51097, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.5682 - val_loss: 0.5110
# Epoch 25/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5335
# Epoch 25: val_loss improved from 0.51097 to 0.47310, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.5333 - val_loss: 0.4731
# Epoch 26/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4975
# Epoch 26: val_loss improved from 0.47310 to 0.42966, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.4936 - val_loss: 0.4297
# Epoch 27/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4393
# Epoch 27: val_loss improved from 0.42966 to 0.38724, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.4489 - val_loss: 0.3872
# Epoch 28/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.3974
# Epoch 28: val_loss improved from 0.38724 to 0.34309, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.4061 - val_loss: 0.3431
# Epoch 29/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.3681
# Epoch 29: val_loss improved from 0.34309 to 0.29420, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3614 - val_loss: 0.2942
# Epoch 30/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3104
# Epoch 30: val_loss improved from 0.29420 to 0.25442, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.3134 - val_loss: 0.2544
# Epoch 31/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2812
# Epoch 31: val_loss improved from 0.25442 to 0.23360, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.2737 - val_loss: 0.2336
# Epoch 32/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2567
# Epoch 32: val_loss improved from 0.23360 to 0.21903, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2516 - val_loss: 0.2190
# Epoch 33/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.2486
# Epoch 33: val_loss improved from 0.21903 to 0.20802, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2330 - val_loss: 0.2080
# Epoch 34/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.2349
# Epoch 34: val_loss improved from 0.20802 to 0.20175, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2184 - val_loss: 0.2018
# Epoch 35/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.2130
# Epoch 35: val_loss improved from 0.20175 to 0.19639, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.2127 - val_loss: 0.1964
# Epoch 36/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1983
# Epoch 36: val_loss improved from 0.19639 to 0.18789, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.2051 - val_loss: 0.1879
# Epoch 37/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1919
# Epoch 37: val_loss improved from 0.18789 to 0.18269, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1963 - val_loss: 0.1827
# Epoch 38/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2021
# Epoch 38: val_loss improved from 0.18269 to 0.17973, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1922 - val_loss: 0.1797
# Epoch 39/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1884
# Epoch 39: val_loss improved from 0.17973 to 0.17625, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1895 - val_loss: 0.1762
# Epoch 40/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1983
# Epoch 40: val_loss did not improve from 0.17625
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1863 - val_loss: 0.1767
# Epoch 41/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1918
# Epoch 41: val_loss improved from 0.17625 to 0.17041, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1872 - val_loss: 0.1704
# Epoch 42/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1741
# Epoch 42: val_loss improved from 0.17041 to 0.16941, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1798 - val_loss: 0.1694
# Epoch 43/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1809
# Epoch 43: val_loss improved from 0.16941 to 0.16426, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1798 - val_loss: 0.1643
# Epoch 44/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1664
# Epoch 44: val_loss improved from 0.16426 to 0.16396, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1751 - val_loss: 0.1640
# Epoch 45/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1744
# Epoch 45: val_loss improved from 0.16396 to 0.16002, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1752 - val_loss: 0.1600
# Epoch 46/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1701
# Epoch 46: val_loss improved from 0.16002 to 0.15616, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1709 - val_loss: 0.1562
# Epoch 47/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1717
# Epoch 47: val_loss did not improve from 0.15616
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1694 - val_loss: 0.1581
# Epoch 48/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1573
# Epoch 48: val_loss improved from 0.15616 to 0.15434, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1695 - val_loss: 0.1543
# Epoch 49/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1774
# Epoch 49: val_loss did not improve from 0.15434
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1685 - val_loss: 0.1642
# Epoch 50/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1876
# Epoch 50: val_loss did not improve from 0.15434
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1770 - val_loss: 0.1665
# Epoch 51/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1588
# Epoch 51: val_loss improved from 0.15434 to 0.14995, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1763 - val_loss: 0.1500
# Epoch 52/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1671
# Epoch 52: val_loss did not improve from 0.14995
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1645 - val_loss: 0.1518
# Epoch 53/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1657
# Epoch 53: val_loss did not improve from 0.14995
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1661 - val_loss: 0.1647
# Epoch 54/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1612
# Epoch 54: val_loss improved from 0.14995 to 0.14990, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1745 - val_loss: 0.1499
# Epoch 55/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1602
# Epoch 55: val_loss did not improve from 0.14990
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1635 - val_loss: 0.1506
# Epoch 56/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1587
# Epoch 56: val_loss improved from 0.14990 to 0.14549, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1628 - val_loss: 0.1455
# Epoch 57/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1694
# Epoch 57: val_loss improved from 0.14549 to 0.14458, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1628 - val_loss: 0.1446
# Epoch 58/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1660
# Epoch 58: val_loss did not improve from 0.14458
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1617 - val_loss: 0.1486
# Epoch 59/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1648
# Epoch 59: val_loss did not improve from 0.14458
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.1616 - val_loss: 0.1449
# Epoch 60/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1686
# Epoch 60: val_loss did not improve from 0.14458
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1592 - val_loss: 0.1467
# Epoch 61/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1585
# Epoch 61: val_loss did not improve from 0.14458
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1598 - val_loss: 0.1494
# Epoch 62/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1562
# Epoch 62: val_loss improved from 0.14458 to 0.14177, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1607 - val_loss: 0.1418
# Epoch 63/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1525
# Epoch 63: val_loss improved from 0.14177 to 0.14121, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1566 - val_loss: 0.1412
# Epoch 64/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1546
# Epoch 64: val_loss improved from 0.14121 to 0.13870, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1560 - val_loss: 0.1387
# Epoch 65/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.1550
# Epoch 65: val_loss improved from 0.13870 to 0.13694, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1576 - val_loss: 0.1369
# Epoch 66/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1550
# Epoch 66: val_loss did not improve from 0.13694
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1561 - val_loss: 0.1372
# Epoch 67/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1580
# Epoch 67: val_loss did not improve from 0.13694
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1544 - val_loss: 0.1376
# Epoch 68/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1556
# Epoch 68: val_loss did not improve from 0.13694
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1565 - val_loss: 0.1373
# Epoch 69/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1619
# Epoch 69: val_loss did not improve from 0.13694
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1565 - val_loss: 0.1416
# Epoch 70/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1558
# Epoch 70: val_loss improved from 0.13694 to 0.13639, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1557 - val_loss: 0.1364
# Epoch 71/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1525
# Epoch 71: val_loss did not improve from 0.13639
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1534 - val_loss: 0.1366
# Epoch 72/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1574
# Epoch 72: val_loss did not improve from 0.13639
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1566 - val_loss: 0.1368
# Epoch 73/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1577
# Epoch 73: val_loss did not improve from 0.13639
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1564 - val_loss: 0.1388
# Epoch 74/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1653
# Epoch 74: val_loss did not improve from 0.13639
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1584 - val_loss: 0.1397
# Epoch 75/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1580
# Epoch 75: val_loss improved from 0.13639 to 0.13590, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1548 - val_loss: 0.1359
# Epoch 76/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1484
# Epoch 76: val_loss did not improve from 0.13590
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1545 - val_loss: 0.1441
# Epoch 77/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1573
# Epoch 77: val_loss did not improve from 0.13590
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1578 - val_loss: 0.1383
# Epoch 78/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1645
# Epoch 78: val_loss did not improve from 0.13590
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1598 - val_loss: 0.1392
# Epoch 79/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1553
# Epoch 79: val_loss did not improve from 0.13590
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1548 - val_loss: 0.1396
# Epoch 80/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1452
# Epoch 80: val_loss did not improve from 0.13590
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1537 - val_loss: 0.1404
# Epoch 81/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1649
# Epoch 81: val_loss did not improve from 0.13590
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1553 - val_loss: 0.1424
# Epoch 82/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1617
# Epoch 82: val_loss improved from 0.13590 to 0.13506, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1544 - val_loss: 0.1351
# Epoch 83/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1559
# Epoch 83: val_loss did not improve from 0.13506
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1558 - val_loss: 0.1402
# Epoch 84/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1614
# Epoch 84: val_loss improved from 0.13506 to 0.13488, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1626 - val_loss: 0.1349
# Epoch 85/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1626
# Epoch 85: val_loss improved from 0.13488 to 0.13486, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1518 - val_loss: 0.1349
# Epoch 86/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1508
# Epoch 86: val_loss did not improve from 0.13486
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1520 - val_loss: 0.1375
# Epoch 87/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1363
# Epoch 87: val_loss did not improve from 0.13486
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1521 - val_loss: 0.1369
# Epoch 88/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1521
# Epoch 88: val_loss did not improve from 0.13486
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1521 - val_loss: 0.1399
# Epoch 89/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1542
# Epoch 89: val_loss did not improve from 0.13486
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1549 - val_loss: 0.1434
# Epoch 90/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1499
# Epoch 90: val_loss did not improve from 0.13486
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1573 - val_loss: 0.1378
# Epoch 91/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1541
# Epoch 91: val_loss did not improve from 0.13486
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1525 - val_loss: 0.1359
# Epoch 92/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1475
# Epoch 92: val_loss did not improve from 0.13486
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1515 - val_loss: 0.1389
# Epoch 93/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1619
# Epoch 93: val_loss did not improve from 0.13486
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1519 - val_loss: 0.1359
# Epoch 94/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1495
# Epoch 94: val_loss did not improve from 0.13486
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1534 - val_loss: 0.1373
# Epoch 95/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1569
# Epoch 95: val_loss did not improve from 0.13486
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.1510 - val_loss: 0.1354
# Epoch 96/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1672
# Epoch 96: val_loss improved from 0.13486 to 0.13381, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1558 - val_loss: 0.1338
# Epoch 97/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1464
# Epoch 97: val_loss did not improve from 0.13381
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1505 - val_loss: 0.1345
# Epoch 98/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1491
# Epoch 98: val_loss did not improve from 0.13381
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1511 - val_loss: 0.1395
# Epoch 99/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1637
# Epoch 99: val_loss improved from 0.13381 to 0.13375, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1615 - val_loss: 0.1337
# Epoch 100/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1367
# Epoch 100: val_loss did not improve from 0.13375
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1515 - val_loss: 0.1338
# Epoch 101/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1474
# Epoch 101: val_loss did not improve from 0.13375
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1504 - val_loss: 0.1350
# Epoch 102/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1519
# Epoch 102: val_loss did not improve from 0.13375
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1500 - val_loss: 0.1342
# Epoch 103/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1534
# Epoch 103: val_loss did not improve from 0.13375
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1497 - val_loss: 0.1449
# Epoch 104/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1560
# Epoch 104: val_loss did not improve from 0.13375
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1552 - val_loss: 0.1338
# Epoch 105/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1506
# Epoch 105: val_loss did not improve from 0.13375
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1535 - val_loss: 0.1371
# Epoch 106/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1590
# Epoch 106: val_loss improved from 0.13375 to 0.13317, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1501 - val_loss: 0.1332
# Epoch 107/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1489
# Epoch 107: val_loss improved from 0.13317 to 0.13304, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1509 - val_loss: 0.1330
# Epoch 108/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1524
# Epoch 108: val_loss did not improve from 0.13304
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1494 - val_loss: 0.1375
# Epoch 109/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1524
# Epoch 109: val_loss did not improve from 0.13304
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1496 - val_loss: 0.1379
# Epoch 110/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1321
# Epoch 110: val_loss improved from 0.13304 to 0.13230, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1490 - val_loss: 0.1323
# Epoch 111/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1597
# Epoch 111: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1519 - val_loss: 0.1356
# Epoch 112/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1508
# Epoch 112: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1488 - val_loss: 0.1409
# Epoch 113/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1509
# Epoch 113: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1502 - val_loss: 0.1344
# Epoch 114/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1587
# Epoch 114: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1519 - val_loss: 0.1413
# Epoch 115/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1377
# Epoch 115: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1507 - val_loss: 0.1327
# Epoch 116/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1495
# Epoch 116: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1520 - val_loss: 0.1328
# Epoch 117/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1536
# Epoch 117: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1494 - val_loss: 0.1328
# Epoch 118/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1503
# Epoch 118: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1481 - val_loss: 0.1462
# Epoch 119/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1585
# Epoch 119: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1540 - val_loss: 0.1326
# Epoch 120/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1352
# Epoch 120: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1527 - val_loss: 0.1351
# Epoch 121/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1514
# Epoch 121: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1565 - val_loss: 0.1329
# Epoch 122/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1568
# Epoch 122: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1476 - val_loss: 0.1334
# Epoch 123/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1433
# Epoch 123: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1471 - val_loss: 0.1350
# Epoch 124/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1418
# Epoch 124: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1472 - val_loss: 0.1332
# Epoch 125/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1444
# Epoch 125: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1470 - val_loss: 0.1348
# Epoch 126/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1422
# Epoch 126: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1471 - val_loss: 0.1394
# Epoch 127/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1562
# Epoch 127: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1484 - val_loss: 0.1346
# Epoch 128/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.1613
# Epoch 128: val_loss did not improve from 0.13230
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1541 - val_loss: 0.1400
# Epoch 129/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1505
# Epoch 129: val_loss improved from 0.13230 to 0.13204, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1499 - val_loss: 0.1320
# Epoch 130/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1481
# Epoch 130: val_loss improved from 0.13204 to 0.13111, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.1471 - val_loss: 0.1311
# Epoch 131/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1498
# Epoch 131: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1473 - val_loss: 0.1411
# Epoch 132/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1532
# Epoch 132: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1521 - val_loss: 0.1378
# Epoch 133/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1582
# Epoch 133: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1469 - val_loss: 0.1332
# Epoch 134/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1626
# Epoch 134: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1519 - val_loss: 0.1343
# Epoch 135/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1548
# Epoch 135: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1524 - val_loss: 0.1350
# Epoch 136/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1509
# Epoch 136: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1469 - val_loss: 0.1482
# Epoch 137/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1636
# Epoch 137: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1555 - val_loss: 0.1329
# Epoch 138/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1568
# Epoch 138: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1483 - val_loss: 0.1342
# Epoch 139/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1511
# Epoch 139: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1465 - val_loss: 0.1382
# Epoch 140/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1468
# Epoch 140: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1469 - val_loss: 0.1364
# Epoch 141/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1540
# Epoch 141: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1464 - val_loss: 0.1426
# Epoch 142/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1595
# Epoch 142: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1509 - val_loss: 0.1403
# Epoch 143/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1498
# Epoch 143: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1478 - val_loss: 0.1351
# Epoch 144/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1328
# Epoch 144: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1464 - val_loss: 0.1354
# Epoch 145/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1494
# Epoch 145: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1460 - val_loss: 0.1327
# Epoch 146/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1509
# Epoch 146: val_loss did not improve from 0.13111
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1491 - val_loss: 0.1405
# Epoch 147/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1476
# Epoch 147: val_loss improved from 0.13111 to 0.13079, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1479 - val_loss: 0.1308
# Epoch 148/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1549
# Epoch 148: val_loss did not improve from 0.13079
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1461 - val_loss: 0.1355
# Epoch 149/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1340
# Epoch 149: val_loss did not improve from 0.13079
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1459 - val_loss: 0.1418
# Epoch 150/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1525
# Epoch 150: val_loss did not improve from 0.13079
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1502 - val_loss: 0.1328
# Epoch 151/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1467
# Epoch 151: val_loss did not improve from 0.13079
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1455 - val_loss: 0.1356
# Epoch 152/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1484
# Epoch 152: val_loss did not improve from 0.13079
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1461 - val_loss: 0.1473
# Epoch 153/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1454
# Epoch 153: val_loss did not improve from 0.13079
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1539 - val_loss: 0.1327
# Epoch 154/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1407
# Epoch 154: val_loss did not improve from 0.13079
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1504 - val_loss: 0.1363
# Epoch 155/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1410
# Epoch 155: val_loss improved from 0.13079 to 0.13071, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1455 - val_loss: 0.1307
# Epoch 156/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1522
# Epoch 156: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1452 - val_loss: 0.1400
# Epoch 157/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.1547
# Epoch 157: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1488 - val_loss: 0.1386
# Epoch 158/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1436
# Epoch 158: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1476 - val_loss: 0.1343
# Epoch 159/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1363
# Epoch 159: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1442 - val_loss: 0.1307
# Epoch 160/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1567
# Epoch 160: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1493 - val_loss: 0.1313
# Epoch 161/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1481
# Epoch 161: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1448 - val_loss: 0.1327
# Epoch 162/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.1407
# Epoch 162: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1445 - val_loss: 0.1410
# Epoch 163/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1465
# Epoch 163: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1496 - val_loss: 0.1368
# Epoch 164/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1476
# Epoch 164: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1452 - val_loss: 0.1309
# Epoch 165/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1515
# Epoch 165: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1450 - val_loss: 0.1323
# Epoch 166/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1444
# Epoch 166: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1447 - val_loss: 0.1317
# Epoch 167/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1338
# Epoch 167: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1473 - val_loss: 0.1328
# Epoch 168/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1425
# Epoch 168: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1440 - val_loss: 0.1375
# Epoch 169/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1535
# Epoch 169: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1449 - val_loss: 0.1312
# Epoch 170/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1445
# Epoch 170: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1485 - val_loss: 0.1322
# Epoch 171/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1562
# Epoch 171: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1483 - val_loss: 0.1396
# Epoch 172/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1438
# Epoch 172: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1479 - val_loss: 0.1393
# Epoch 173/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1434
# Epoch 173: val_loss did not improve from 0.13071
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1469 - val_loss: 0.1347
# Epoch 174/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1349
# Epoch 174: val_loss improved from 0.13071 to 0.13065, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1437 - val_loss: 0.1307
# Epoch 175/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1345
# Epoch 175: val_loss did not improve from 0.13065
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1455 - val_loss: 0.1319
# Epoch 176/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1366
# Epoch 176: val_loss improved from 0.13065 to 0.12866, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.1435 - val_loss: 0.1287
# Epoch 177/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1384
# Epoch 177: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1453 - val_loss: 0.1287
# Epoch 178/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1524
# Epoch 178: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1447 - val_loss: 0.1409
# Epoch 179/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1569
# Epoch 179: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1496 - val_loss: 0.1332
# Epoch 180/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1478
# Epoch 180: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1432 - val_loss: 0.1380
# Epoch 181/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1469
# Epoch 181: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1470 - val_loss: 0.1359
# Epoch 182/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.1527
# Epoch 182: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1443 - val_loss: 0.1293
# Epoch 183/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1487
# Epoch 183: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1467 - val_loss: 0.1291
# Epoch 184/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1336
# Epoch 184: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1451 - val_loss: 0.1287
# Epoch 185/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1529
# Epoch 185: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1437 - val_loss: 0.1409
# Epoch 186/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1579
# Epoch 186: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1513 - val_loss: 0.1452
# Epoch 187/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1615
# Epoch 187: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1535 - val_loss: 0.1342
# Epoch 188/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1313
# Epoch 188: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1431 - val_loss: 0.1336
# Epoch 189/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1447
# Epoch 189: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1433 - val_loss: 0.1396
# Epoch 190/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1468
# Epoch 190: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1473 - val_loss: 0.1352
# Epoch 191/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1375
# Epoch 191: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1431 - val_loss: 0.1346
# Epoch 192/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1576
# Epoch 192: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1508 - val_loss: 0.1359
# Epoch 193/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1311
# Epoch 193: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1444 - val_loss: 0.1330
# Epoch 194/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1435
# Epoch 194: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1424 - val_loss: 0.1316
# Epoch 195/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1228
# Epoch 195: val_loss did not improve from 0.12866
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1421 - val_loss: 0.1319
# Epoch 196/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1321
# Epoch 196: val_loss improved from 0.12866 to 0.12815, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1423 - val_loss: 0.1282
# Epoch 197/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1377
# Epoch 197: val_loss did not improve from 0.12815
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1439 - val_loss: 0.1292
# Epoch 198/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1441
# Epoch 198: val_loss did not improve from 0.12815
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1423 - val_loss: 0.1414
# Epoch 199/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1374
# Epoch 199: val_loss did not improve from 0.12815
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1492 - val_loss: 0.1284
# Epoch 200/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1557
# Epoch 200: val_loss did not improve from 0.12815
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1450 - val_loss: 0.1308
# Epoch 201/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1374
# Epoch 201: val_loss improved from 0.12815 to 0.12784, saving model to best_model.keras
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1422 - val_loss: 0.1278
# Epoch 202/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.1457
# Epoch 202: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1437 - val_loss: 0.1289
# Epoch 203/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1484
# Epoch 203: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1459 - val_loss: 0.1305
# Epoch 204/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1392
# Epoch 204: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1421 - val_loss: 0.1291
# Epoch 205/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1449
# Epoch 205: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1446 - val_loss: 0.1337
# Epoch 206/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1424
# Epoch 206: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1435 - val_loss: 0.1320
# Epoch 207/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1464
# Epoch 207: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1416 - val_loss: 0.1321
# Epoch 208/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1224
# Epoch 208: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1413 - val_loss: 0.1310
# Epoch 209/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1558
# Epoch 209: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1485 - val_loss: 0.1287
# Epoch 210/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1401
# Epoch 210: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1418 - val_loss: 0.1281
# Epoch 211/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1473
# Epoch 211: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1428 - val_loss: 0.1310
# Epoch 212/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1490
# Epoch 212: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1475 - val_loss: 0.1329
# Epoch 213/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1455
# Epoch 213: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1429 - val_loss: 0.1325
# Epoch 214/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1399
# Epoch 214: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1424 - val_loss: 0.1385
# Epoch 215/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1542
# Epoch 215: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1446 - val_loss: 0.1338
# Epoch 216/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1534
# Epoch 216: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1498 - val_loss: 0.1370
# Epoch 217/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1411
# Epoch 217: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1461 - val_loss: 0.1444
# Epoch 218/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1601
# Epoch 218: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1509 - val_loss: 0.1329
# Epoch 219/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1521
# Epoch 219: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1416 - val_loss: 0.1321
# Epoch 220/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1396
# Epoch 220: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1428 - val_loss: 0.1365
# Epoch 221/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1463
# Epoch 221: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1434 - val_loss: 0.1337
# Epoch 222/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1516
# Epoch 222: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1421 - val_loss: 0.1395
# Epoch 223/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1272
# Epoch 223: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1454 - val_loss: 0.1311
# Epoch 224/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1362
# Epoch 224: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1452 - val_loss: 0.1300
# Epoch 225/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1419
# Epoch 225: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1416 - val_loss: 0.1297
# Epoch 226/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1410
# Epoch 226: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.1414 - val_loss: 0.1370
# Epoch 227/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1207
# Epoch 227: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1439 - val_loss: 0.1286
# Epoch 228/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1422
# Epoch 228: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.1418 - val_loss: 0.1286
# Epoch 229/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.1550
# Epoch 229: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1469 - val_loss: 0.1286
# Epoch 230/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1449
# Epoch 230: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1458 - val_loss: 0.1281
# Epoch 231/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1280
# Epoch 231: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1410 - val_loss: 0.1347
# Epoch 232/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1491
# Epoch 232: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1448 - val_loss: 0.1309
# Epoch 233/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1468
# Epoch 233: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1403 - val_loss: 0.1298
# Epoch 234/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1390
# Epoch 234: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.1405 - val_loss: 0.1356
# Epoch 235/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1437
# Epoch 235: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.1427 - val_loss: 0.1287
# Epoch 236/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1515
# Epoch 236: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1447 - val_loss: 0.1289
# Epoch 237/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1456
# Epoch 237: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.1403 - val_loss: 0.1374
# Epoch 238/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1458
# Epoch 238: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1459 - val_loss: 0.1345
# Epoch 239/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1513
# Epoch 239: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1435 - val_loss: 0.1291
# Epoch 240/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1413
# Epoch 240: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1405 - val_loss: 0.1302
# Epoch 241/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1502
# Epoch 241: val_loss did not improve from 0.12784
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.1401 - val_loss: 0.1292
# Epoch 242/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1424
# ...
# Epoch 2117/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0409
# Epoch 2117: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0392 - val_loss: 0.0711
# Epoch 2118/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0436
# Epoch 2118: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0516 - val_loss: 0.0588
# Epoch 2119/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0396
# Epoch 2119: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0375 - val_loss: 0.0562
# Epoch 2120/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0263
# Epoch 2120: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0366 - val_loss: 0.0587
# Epoch 2121/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0367
# Epoch 2121: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0369 - val_loss: 0.0663
# Epoch 2122/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0484
# Epoch 2122: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0471 - val_loss: 0.0586
# Epoch 2123/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0398
# Epoch 2123: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0390 - val_loss: 0.0587
# Epoch 2124/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0396
# Epoch 2124: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0377 - val_loss: 0.0671
# Epoch 2125/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0525
# Epoch 2125: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0509 - val_loss: 0.0658
# Epoch 2126/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0361
# Epoch 2126: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0456 - val_loss: 0.0603
# Epoch 2127/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0418
# Epoch 2127: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0386 - val_loss: 0.0567
# Epoch 2128/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0386
# Epoch 2128: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0380 - val_loss: 0.0609
# Epoch 2129/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0401
# Epoch 2129: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0391 - val_loss: 0.0717
# Epoch 2130/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0561
# Epoch 2130: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0512 - val_loss: 0.0588
# Epoch 2131/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0424
# Epoch 2131: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0405 - val_loss: 0.0572
# Epoch 2132/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0385
# Epoch 2132: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0367 - val_loss: 0.0705
# Epoch 2133/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0531
# Epoch 2133: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0518 - val_loss: 0.0553
# Epoch 2134/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0369
# Epoch 2134: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0360 - val_loss: 0.0562
# Epoch 2135/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0398
# Epoch 2135: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0370 - val_loss: 0.0728
# Epoch 2136/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0565
# Epoch 2136: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0519 - val_loss: 0.0583
# Epoch 2137/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0292
# Epoch 2137: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0386 - val_loss: 0.0628
# Epoch 2138/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0443
# Epoch 2138: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0410 - val_loss: 0.0688
# Epoch 2139/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0522
# Epoch 2139: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0497 - val_loss: 0.0734
# Epoch 2140/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0522
# Epoch 2140: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0521 - val_loss: 0.0598
# Epoch 2141/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0416
# Epoch 2141: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0382 - val_loss: 0.0572
# Epoch 2142/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0411
# Epoch 2142: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0385 - val_loss: 0.0639
# Epoch 2143/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0453
# Epoch 2143: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0429 - val_loss: 0.0573
# Epoch 2144/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0253
# Epoch 2144: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0372 - val_loss: 0.0596
# Epoch 2145/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0417
# Epoch 2145: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0395 - val_loss: 0.0567
# Epoch 2146/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0373
# Epoch 2146: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0366 - val_loss: 0.0562
# Epoch 2147/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0383
# Epoch 2147: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0357 - val_loss: 0.0566
# Epoch 2148/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0402
# Epoch 2148: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0378 - val_loss: 0.0699
# Epoch 2149/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0564
# Epoch 2149: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0529 - val_loss: 0.0725
# Epoch 2150/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0551
# Epoch 2150: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0515 - val_loss: 0.0726
# Epoch 2151/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0538
# Epoch 2151: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0513 - val_loss: 0.0634
# Epoch 2152/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0469
# Epoch 2152: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0439 - val_loss: 0.0598
# Epoch 2153/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0389
# Epoch 2153: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0390 - val_loss: 0.0587
# Epoch 2154/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0398
# Epoch 2154: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0380 - val_loss: 0.0565
# Epoch 2155/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0423
# Epoch 2155: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0399 - val_loss: 0.0629
# Epoch 2156/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0473
# Epoch 2156: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0451 - val_loss: 0.0588
# Epoch 2157/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0424
# Epoch 2157: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0399 - val_loss: 0.0558
# Epoch 2158/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0386
# Epoch 2158: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0366 - val_loss: 0.0586
# Epoch 2159/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0408
# Epoch 2159: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0384 - val_loss: 0.0579
# Epoch 2160/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0384
# Epoch 2160: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0371 - val_loss: 0.0691
# Epoch 2161/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0396
# Epoch 2161: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0471 - val_loss: 0.0609
# Epoch 2162/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0414
# Epoch 2162: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0397 - val_loss: 0.0588
# Epoch 2163/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0358
# Epoch 2163: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0370 - val_loss: 0.0647
# Epoch 2164/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0472
# Epoch 2164: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0440 - val_loss: 0.0601
# Epoch 2165/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0443
# Epoch 2165: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0410 - val_loss: 0.0579
# Epoch 2166/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0387
# Epoch 2166: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0401 - val_loss: 0.0614
# Epoch 2167/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0428
# Epoch 2167: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0408 - val_loss: 0.0598
# Epoch 2168/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0410
# Epoch 2168: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0380 - val_loss: 0.0775
# Epoch 2169/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0522
# Epoch 2169: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0593 - val_loss: 0.0563
# Epoch 2170/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0376
# Epoch 2170: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0365 - val_loss: 0.0658
# Epoch 2171/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0516
# Epoch 2171: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0487 - val_loss: 0.0596
# Epoch 2172/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0385
# Epoch 2172: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0384 - val_loss: 0.0569
# Epoch 2173/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0388
# Epoch 2173: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0388 - val_loss: 0.0570
# Epoch 2174/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0373
# Epoch 2174: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0362 - val_loss: 0.0661
# Epoch 2175/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0470
# Epoch 2175: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0457 - val_loss: 0.0559
# Epoch 2176/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0388
# Epoch 2176: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0370 - val_loss: 0.0606
# Epoch 2177/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0447
# Epoch 2177: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0421 - val_loss: 0.0568
# Epoch 2178/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0386
# Epoch 2178: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0366 - val_loss: 0.0623
# Epoch 2179/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0445
# Epoch 2179: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0424 - val_loss: 0.0566
# Epoch 2180/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0370
# Epoch 2180: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0364 - val_loss: 0.0640
# Epoch 2181/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0453
# Epoch 2181: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0421 - val_loss: 0.0569
# Epoch 2182/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0392
# Epoch 2182: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0379 - val_loss: 0.0569
# Epoch 2183/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0385
# Epoch 2183: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0387 - val_loss: 0.0647
# Epoch 2184/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0358
# Epoch 2184: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0446 - val_loss: 0.0552
# Epoch 2185/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0356
# Epoch 2185: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0358 - val_loss: 0.0591
# Epoch 2186/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0310
# Epoch 2186: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0409 - val_loss: 0.0546
# Epoch 2187/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0350
# Epoch 2187: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0353 - val_loss: 0.0584
# Epoch 2188/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0396
# Epoch 2188: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0373 - val_loss: 0.0828
# Epoch 2189/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0709
# Epoch 2189: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0682 - val_loss: 0.0580
# Epoch 2190/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0398
# Epoch 2190: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0375 - val_loss: 0.0582
# Epoch 2191/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0364
# Epoch 2191: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0371 - val_loss: 0.0573
# Epoch 2192/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0383
# Epoch 2192: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0367 - val_loss: 0.0564
# Epoch 2193/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0380
# Epoch 2193: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0374 - val_loss: 0.0559
# Epoch 2194/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0369
# Epoch 2194: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0358 - val_loss: 0.0580
# Epoch 2195/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0412
# Epoch 2195: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0389 - val_loss: 0.0640
# Epoch 2196/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0362
# Epoch 2196: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0468 - val_loss: 0.0645
# Epoch 2197/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0462
# Epoch 2197: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0455 - val_loss: 0.0686
# Epoch 2198/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0509
# Epoch 2198: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0473 - val_loss: 0.0574
# Epoch 2199/3000
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0371
# Epoch 2199: val_loss did not improve from 0.05454
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0367 - val_loss: 0.0551
# Epoch 2199: early stopping
# Restoring model weights from the end of the best epoch: 2099.
# best epoch =  2099
# smallest training loss = 0.035300616174936295
# smallest validation loss = 0.05454247072339058

# %%
# (f) Compare model predictions with training dataset
import matplotlib.pyplot as plt

# Predict on training set
train_predictions = model.predict(xarray, verbose=0)

# Convert back to original units
train_actual_VL = yarray[:, 0] * VLmed
train_actual_Wd = yarray[:, 1] * Wdmed
train_pred_VL = train_predictions[:, 0] * VLmed
train_pred_Wd = train_predictions[:, 1] * Wdmed

# Calculate mean absolute error for training set
mae_train_VL = np.mean(np.abs(train_actual_VL - train_pred_VL))
mae_train_Wd = np.mean(np.abs(train_actual_Wd - train_pred_Wd))
mae_train_overall = np.mean(np.abs(yarray - train_predictions))

print("=" * 60)
print("(f) Training Set Prediction Results")
print("=" * 60)
print(f"Training MAE (normalized): {mae_train_overall:.6f}")
print(f"Training MAE - Voltage VL: {mae_train_VL:.4f} V")
print(f"Training MAE - Power Wd: {mae_train_Wd:.4f} W")
print("=" * 60)
# Out:
# ============================================================
# (f) Training Set Prediction Results
# ============================================================
# Training MAE (normalized): 0.036163
# Training MAE - Voltage VL: 0.5819 V
# Training MAE - Power Wd: 5.9126 W
# ============================================================

# %%
# Create log-log plot for training set
fig, ax = plt.subplots(figsize=(10, 8))

# Plot predicted vs actual power output (log-log plot)
ax.loglog(train_actual_Wd, train_pred_Wd, 'bo', markersize=8, alpha=0.6, label='Training data points')
ax.loglog([train_actual_Wd.min(), train_actual_Wd.max()], 
          [train_actual_Wd.min(), train_actual_Wd.max()], 
          'r--', linewidth=2, label='Ideal fit line (y=x)')

ax.set_xlabel('Actual Power Output Wd (W)', fontsize=12)
ax.set_ylabel('Predicted Power Output Wd (W)', fontsize=12)
ax.set_title('Training Set: Predicted vs Actual Power (Log-Log Plot)', fontsize=14, fontweight='bold')
ax.grid(True, which="both", ls="-", alpha=0.3)
ax.legend(fontsize=11)

plt.tight_layout()
plt.show()

print(f"Training samples: {len(train_actual_Wd)}")
print(f"Power range: {train_actual_Wd.min():.2f} W to {train_actual_Wd.max():.2f} W")
# Out:
# Training samples: 36
# Power range: 70.30 W to 224.40 W

# %%
# (g) Compare model predictions with validation dataset

# Predict on validation set
val_predictions = model.predict(xarray_val, verbose=0)

# Convert back to original units
val_actual_VL = yarray_val[:, 0] * VLmed
val_actual_Wd = yarray_val[:, 1] * Wdmed
val_pred_VL = val_predictions[:, 0] * VLmed
val_pred_Wd = val_predictions[:, 1] * Wdmed

# Calculate mean absolute error for validation set
mae_val_VL = np.mean(np.abs(val_actual_VL - val_pred_VL))
mae_val_Wd = np.mean(np.abs(val_actual_Wd - val_pred_Wd))
mae_val_overall = np.mean(np.abs(yarray_val - val_predictions))

print("=" * 60)
print("(g) Validation Set Prediction Results")
print("=" * 60)
print(f"Validation MAE (normalized): {mae_val_overall:.6f}")
print(f"Validation MAE - Voltage VL: {mae_val_VL:.4f} V")
print(f"Validation MAE - Power Wd: {mae_val_Wd:.4f} W")
print("=" * 60)
# Out:
# ============================================================
# (g) Validation Set Prediction Results
# ============================================================
# Validation MAE (normalized): 0.054542
# Validation MAE - Voltage VL: 0.9418 V
# Validation MAE - Power Wd: 8.6449 W
# ============================================================

# %%
# Create log-log plot for validation set
fig, ax = plt.subplots(figsize=(10, 8))

# Plot predicted vs actual power output (log-log plot)
ax.loglog(val_actual_Wd, val_pred_Wd, 'gs', markersize=8, alpha=0.6, label='Validation data points')
ax.loglog([val_actual_Wd.min(), val_actual_Wd.max()], 
          [val_actual_Wd.min(), val_actual_Wd.max()], 
          'r--', linewidth=2, label='Ideal fit line (y=x)')

ax.set_xlabel('Actual Power Output Wd (W)', fontsize=12)
ax.set_ylabel('Predicted Power Output Wd (W)', fontsize=12)
ax.set_title('Validation Set: Predicted vs Actual Power (Log-Log Plot)', fontsize=14, fontweight='bold')
ax.grid(True, which="both", ls="-", alpha=0.3)
ax.legend(fontsize=11)

plt.tight_layout()
plt.show()

print(f"Validation samples: {len(val_actual_Wd)}")
print(f"Power range: {val_actual_Wd.min():.2f} W to {val_actual_Wd.max():.2f} W")
# Out:
# Validation samples: 18
# Power range: 62.20 W to 191.40 W

# %%
# (h) Create power output surface plot
# Fixed air temperature Ta = 20°C
# RL range: 4 to 8 Ohms
# ID range: 500 to 1900 W/m²

# Create grid
RL_range = np.linspace(4, 8, 50)
ID_range = np.linspace(500, 1900, 50)
RL_grid, ID_grid = np.meshgrid(RL_range, ID_range)

# Fixed temperature Ta = 20°C
Ta_fixed = 20.0

# Create input data (normalized)
n_points = RL_grid.size
input_data = np.zeros((n_points, 3))
input_data[:, 0] = (Ta_fixed / Tamed) * np.ones(n_points)  # Normalized temperature
input_data[:, 1] = (ID_grid.flatten() / IDmed)              # Normalized irradiance
input_data[:, 2] = (RL_grid.flatten() / RLmed)              # Normalized load resistance

# Make predictions
predictions_surface = model.predict(input_data, verbose=0)

# Convert power output back to original units
Wd_predicted = predictions_surface[:, 1] * Wdmed
Wd_grid = Wd_predicted.reshape(RL_grid.shape)

print("=" * 60)
print("(h) Power Output Surface Prediction")
print("=" * 60)
print(f"Fixed temperature: Ta = {Ta_fixed}°C")
print(f"Load resistance range: {RL_range.min():.1f} Ω to {RL_range.max():.1f} Ω")
print(f"Irradiance range: {ID_range.min():.0f} W/m² to {ID_range.max():.0f} W/m²")
print(f"Predicted power range: {Wd_grid.min():.2f} W to {Wd_grid.max():.2f} W")
print("=" * 60)
# Out:
# ============================================================
# (h) Power Output Surface Prediction
# ============================================================
# Fixed temperature: Ta = 20.0°C
# Load resistance range: 4.0 Ω to 8.0 Ω
# Irradiance range: 500 W/m² to 1900 W/m²
# Predicted power range: 88.79 W to 212.12 W
# ============================================================

# %%
# Plot 3D surface
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(14, 10))
ax = fig.add_subplot(111, projection='3d')

# Plot surface
surf = ax.plot_surface(ID_grid, RL_grid, Wd_grid, cmap='viridis', 
                       alpha=0.9, edgecolor='none', antialiased=True)

# Add contour projection
contours = ax.contour(ID_grid, RL_grid, Wd_grid, zdir='z', offset=Wd_grid.min(), 
                      cmap='viridis', alpha=0.4, linewidths=1)

# Set labels
ax.set_xlabel('Irradiance ID (W/m²)', fontsize=12, labelpad=10)
ax.set_ylabel('Load Resistance RL (Ω)', fontsize=12, labelpad=10)
ax.set_zlabel('Power Output Wd (W)', fontsize=12, labelpad=10)
ax.set_title(f'PV System Power Output Surface\n(Fixed Temperature Ta = {Ta_fixed}°C)', 
             fontsize=14, fontweight='bold', pad=20)

# Add color bar
cbar = fig.colorbar(surf, ax=ax, shrink=0.5, aspect=10)
cbar.set_label('Power Output (W)', fontsize=11)

# Adjust viewing angle
ax.view_init(elev=25, azim=45)

plt.tight_layout()
plt.show()
